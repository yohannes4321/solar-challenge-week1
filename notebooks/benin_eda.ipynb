# %% [markdown]
# Load and inspect

# %%
 
import pandas as pd

df = pd.read_csv("../data/benin-malanville.csv", parse_dates=["Timestamp"])

# %% [markdown]
#  2. Summary Statistics & Missing-Value Report

# %% [markdown]
# Outlier Detection

# %% [markdown]
#  2. Summary Statistics & Missing-Value Report

# %%
# Summary statistics
df.describe()

# Missing values
missing = df.isna().sum()
missing[missing > 0].sort_values(ascending=False)

# Columns with >5% nulls
null_percent = (missing / len(df)) * 100
high_nulls = null_percent[null_percent > 5]

# %% [markdown]
# OUTLAIER DETECTION

# %% [markdown]
# 3. Outlier Detection & Basic Cleaning

# %%
from scipy.stats import zscore

columns_to_check = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']
z_scores = df[columns_to_check].apply(zscore)
outliers = (z_scores.abs() > 3).any(axis=1)

# Optional: mark or drop outliers
df_clean = df[~outliers]

# %% [markdown]
# Impute or Drop Missing:

# %%
# Impute using median
df_clean[columns_to_check] = df_clean[columns_to_check].fillna(df_clean[columns_to_check].median())
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12200\431164729.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[columns_to_check] = df_clean[columns_to_check].fillna(df_clean[columns_to_check].median())

# %%
# Make a proper deep copy to avoid the warning
df_clean = df[~outliers].copy()

# Now impute safely using .loc
df_clean.loc[:, columns_to_check] = df_clean[columns_to_check].fillna(df_clean[columns_to_check].median())

# %% [markdown]
#  4. Time Series Analysis

# %%
import matplotlib.pyplot as plt

df_clean.set_index('Timestamp')[['GHI', 'DNI', 'DHI', 'Tamb']].plot(subplots=True, figsize=(12, 10))
# Out:
# array([<Axes: xlabel='Timestamp'>, <Axes: xlabel='Timestamp'>,
#        <Axes: xlabel='Timestamp'>, <Axes: xlabel='Timestamp'>],
#       dtype=object)

# %% [markdown]
# 4. Time Series Analysis

# %%
df_clean.set_index('Timestamp').resample('D').mean()[['GHI', 'Tamb']].plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %% [markdown]
# 5. Cleaning Impact

# %%
import seaborn as sns

df_clean.groupby('Cleaning')[['ModA', 'ModB']].mean().plot(kind='bar', title='ModA & ModB Avg Pre/Post Cleaning')
# Out:
# <Axes: title={'center': 'ModA & ModB Avg Pre/Post Cleaning'}, xlabel='Cleaning'>

# %% [markdown]
#  6. Correlation & Relationship Analysis
#
#
# Heatmap:

# %%
sns.heatmap(df_clean[['GHI', 'DNI', 'DHI', 'TModA', 'TModB']].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Scatter Plots:

# %%
sns.scatterplot(data=df_clean, x='WS', y='GHI')
sns.scatterplot(data=df_clean, x='RH', y='Tamb')
# Out:
# <Axes: xlabel='WS', ylabel='GHI'>

# %% [markdown]
#  7. Wind & Distribution Analysis

# %%
# !pip install windrose
# Out:
# Requirement already satisfied: windrose in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (1.9.2)
# Requirement already satisfied: matplotlib>=3 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from windrose) (3.10.3)
# Requirement already satisfied: numpy>=1.21 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from windrose) (2.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from matplotlib>=3->windrose) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from matplotlib>=3->windrose) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from matplotlib>=3->windrose) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from matplotlib>=3->windrose) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from matplotlib>=3->windrose) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from matplotlib>=3->windrose) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from matplotlib>=3->windrose) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from matplotlib>=3->windrose) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\downloads\solar-challenge-week1\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3->windrose) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Use Windrose Toolkit or matplotlib's polar plots
# pip install windrose
from windrose import WindroseAxes

ax = WindroseAxes.from_ax()
ax.bar(df_clean['WD'], df_clean['WS'], normed=True, opening=0.8, edgecolor='white')

# %% [markdown]
# Histogram:

# %%
df_clean['GHI'].hist(bins=50)
df_clean['WS'].hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# 8. Temperature Analysis

# %%
sns.scatterplot(data=df_clean, x='RH', y='Tamb')
sns.scatterplot(data=df_clean, x='RH', y='GHI')
# Out:
# <Axes: xlabel='RH', ylabel='Tamb'>

# %% [markdown]
# 9. Bubble Chart

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_clean['GHI'], df_clean['Tamb'], s=df_clean['RH'], alpha=0.5)
plt.xlabel('GHI')
plt.ylabel('Tamb')
plt.title('GHI vs Tamb with RH as bubble size')
# Out:
# Text(0.5, 1.0, 'GHI vs Tamb with RH as bubble size')

# %% [markdown]
#  Optional Enhancements (KPIs for extra credit)

# %%
df_clean['hour'] = df_clean['Timestamp'].dt.hour
df_clean.groupby('hour')['GHI'].mean().plot()
# Out:
# <Axes: xlabel='hour'>
